# %%
import pandas as pd
import numpy as np

# %%
import os
os.makedirs('Data/',exist_ok=True) # Confirm folder created
os.listdir("Data/")
# Out:
# ['title_basics.csv.gz', 'title_akas.csv.gz']

# %%
# retrieving akas url
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
akas = pd.read_csv(akas_url, sep='\t', low_memory=False, compression = 'gzip')

# showing preview of akas data
akas.info()
akas.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36962438 entries, 0 to 36962437
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.2+ GB
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
# retrieving basic url
basics_url="http://datasets.imdbws.com/title.basics.tsv.gz"
basics = pd.read_csv(basics_url, sep='\t', low_memory=False, compression = 'gzip')

# showing preview of akas data
basics.info()
basics.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10106340 entries, 0 to 10106339
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 693.9+ MB
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# retrieving ratings url
ratings_url="http://datasets.imdbws.com/title.ratings.tsv.gz"
ratings = pd.read_csv(ratings_url, sep='\t', low_memory=False, compression = 'gzip')

# showing preview of akas data
ratings.info()
ratings.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1341659 entries, 0 to 1341658
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1341659 non-null  object
#  1   averageRating  1341659 non-null  float64
#  2   numVotes       1341659 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.7+ MB
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1989
# 1  tt0000002            5.8       264
# 2  tt0000003            6.5      1863
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2648

# %% [markdown]
# ## AKAS

# %% [markdown]
# ### Replacing "\N" with np.nan

# %%
# Filtering to keep only US movies
us_movies = akas[(akas['region'] == 'US')]

# %%
akas.replace({'\\N':np.nan},inplace=True)

# %%
# displaying the first 5 rows
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay            NaN               0
# 1          NaN  literal title               0
# 2  imdbDisplay            NaN               0
# 3  imdbDisplay            NaN               0
# 4  imdbDisplay            NaN               0

# %% [markdown]
# ## Basics

# %% [markdown]
# ### Replacing "\N" with np.nan

# %%
basics.replace({'\\N':np.nan},inplace=True)

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0            True
# 1            True
# 2            True
# 3            True
# 4            True
#             ...
# 10106335     True
# 10106336     True
# 10106337     True
# 10106338     True
# 10106339    False
# Name: tconst, Length: 10106340, dtype: bool

# %%
basics = basics[keepers]
basics
# Out:
#              tconst  titleType            primaryTitle  \
# 0         tt0000001      short              Carmencita
# 1         tt0000002      short  Le clown et ses chiens
# 2         tt0000003      short          Pauvre Pierrot
# 3         tt0000004      short             Un bon bock
# 4         tt0000005      short        Blacksmith Scene
# ...             ...        ...                     ...
# 10106334  tt9916846  tvEpisode           Episode #3.18
# 10106335  tt9916848  tvEpisode           Episode #3.17
# 10106336  tt9916850  tvEpisode           Episode #3.19
# 10106337  tt9916852  tvEpisode           Episode #3.20
# 10106338  tt9916856      short                The Wind
#
#                    originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                     Carmencita       0      1894     NaN              1
# 1         Le clown et ses chiens       0      1892     NaN              5
# 2                 Pauvre Pierrot       0      1892     NaN              4
# 3                    Un bon bock       0      1892     NaN             12
# 4               Blacksmith Scene       0      1893     NaN              1
# ...                          ...     ...       ...     ...            ...
# 10106334           Episode #3.18       0      2009     NaN            NaN
# 10106335           Episode #3.17       0      2009     NaN            NaN
# 10106336           Episode #3.19       0      2010     NaN            NaN
# 10106337           Episode #3.20       0      2010     NaN            NaN
# 10106338                The Wind       0      2015     NaN             27
#
#                             genres
# 0                Documentary,Short
# 1                  Animation,Short
# 2         Animation,Comedy,Romance
# 3                  Animation,Short
# 4                     Comedy,Short
# ...                            ...
# 10106334       Action,Drama,Family
# 10106335       Action,Drama,Family
# 10106336       Action,Drama,Family
# 10106337       Action,Drama,Family
# 10106338                     Short
#
# [7239193 rows x 9 columns]

# %% [markdown]
# ### ELIMINATION

# %%
# Eliminate movies that are null for runtimeMinutes
basics = basics[basics['runtimeMinutes'].notna()]

# %%
# Eliminate movies that are null for genres.
basics = basics[basics['genres'].notna()]

# %%
# Keeping only the title type == movie 
basics = basics[basics.titleType == 'movie']

# %%
basics
# Out:
#              tconst titleType  \
# 8         tt0000009     movie
# 144       tt0000147     movie
# 570       tt0000574     movie
# 587       tt0000591     movie
# 672       tt0000679     movie
# ...             ...       ...
# 10106190  tt9916538     movie
# 10106231  tt9916622     movie
# 10106258  tt9916680     movie
# 10106280  tt9916730     movie
# 10106290  tt9916754     movie
#
#                                                primaryTitle  \
# 8                                                Miss Jerry
# 144                           The Corbett-Fitzsimmons Fight
# 570                             The Story of the Kelly Gang
# 587                                        The Prodigal Son
# 672                          The Fairylogue and Radio-Plays
# ...                                                     ...
# 10106190                                Kuambil Lagi Hatiku
# 10106231        Rodolpho Teóphilo - O Legado de um Pioneiro
# 10106258  De la ilusión al desconcierto: cine colombiano...
# 10106280                                             6 Gunn
# 10106290                     Chico Albuquerque - Revelações
#
#                                               originalTitle isAdult startYear  \
# 8                                                Miss Jerry       0      1894
# 144                           The Corbett-Fitzsimmons Fight       0      1897
# 570                             The Story of the Kelly Gang       0      1906
# 587                                       L'enfant prodigue       0      1907
# 672                          The Fairylogue and Radio-Plays       0      1908
# ...                                                     ...     ...       ...
# 10106190                                Kuambil Lagi Hatiku       0      2019
# 10106231        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 10106258  De la ilusión al desconcierto: cine colombiano...       0      2007
# 10106280                                             6 Gunn       0      2017
# 10106290                     Chico Albuquerque - Revelações       0      2013
#
#          endYear runtimeMinutes                      genres
# 8            NaN             45                     Romance
# 144          NaN            100      Documentary,News,Sport
# 570          NaN             70  Action,Adventure,Biography
# 587          NaN             90                       Drama
# 672          NaN            120           Adventure,Fantasy
# ...          ...            ...                         ...
# 10106190     NaN            123                       Drama
# 10106231     NaN             57                 Documentary
# 10106258     NaN            100                 Documentary
# 10106280     NaN            116                       Drama
# 10106290     NaN             49                 Documentary
#
# [386379 rows x 9 columns]

# %%
# Eliminate the null values in the "startYear" column so we can convert it to a float
basics = basics[basics['startYear'].notna()]

# %%
# Convert the "startYear" column to float.
basics['startYear'] = basics['startYear'].astype(float)
# Confirm the datatype
basics.dtypes
# Out:
# /var/folders/j7/rq_q1cb16yx0w__bmvd7lzx80000gn/T/ipykernel_19396/3532062230.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   basics['startYear'] = basics['startYear'].astype(float)
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult            object
# startYear         float64
# endYear            object
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
# Filtering the dataframe using startYear. Keeping the years between 2000-2021
basics = basics[(basics.startYear >=2000) & (basics.startYear <=2021)]

# %%
# Exclude movies that are included in the documentary category.
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %% [markdown]
# ## Ratings

# %% [markdown]
# ### Replacing "\N" with np.nan

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers = ratings['tconst'].isin(basics['tconst'])
keepers
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1341654     True
# 1341655    False
# 1341656    False
# 1341657    False
# 1341658    False
# Name: tconst, Length: 1341659, dtype: bool

# %%
ratings.replace({'\\N':np.nan},inplace=True)

# %% [markdown]
# ### Saving each file to a compressed csv file

# %%
## Save current dataframe to file.
akas.to_csv("Data/title_akas.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
akas = pd.read_csv("Data/title_akas.csv.gz", low_memory = False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay            NaN              0.0
# 1          NaN  literal title              0.0
# 2  imdbDisplay            NaN              0.0
# 3  imdbDisplay            NaN              0.0
# 4  imdbDisplay            NaN              0.0

# %%
## Save current dataframe to file.
basics.to_csv("Data/title_basics.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
basics = pd.read_csv("Data/title_basics.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2              90                   Drama
# 3             122                   Drama
# 4             100    Comedy,Horror,Sci-Fi

# %%
# Save current dataframe to file.
ratings.to_csv("Data/title_ratings.csv.gz",compression='gzip',index=False)

# %%
# Open saved file and preview again
ratings = pd.read_csv("Data/title_ratings.csv.gz", low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1989
# 1  tt0000002            5.8       264
# 2  tt0000003            6.5      1863
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2648
